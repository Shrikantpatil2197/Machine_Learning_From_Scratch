# %%
'''
Illustrates a simple regression task on 
simulated data. 

Trying to find polynomial approximations 
to a sinusoid

It gives an idea how 
non linear regression works

/home/splab-ece/deepl/nonlinear.ipynb

'''

from __future__ import print_function
import numpy as np
import matplotlib.pyplot as plt


def SimulData():
        # Simulate some data for training 
        np.random.seed(42)
        x_train = np.arange(0,10, 0.25 )
        x_train = x_train + 1.0/3.0 * np.random.randn(x_train.size);
        y_train  = np.cos( x_train  * np.pi /7) +  0.1 * np.random.randn(x_train.size);

        x_test = np.arange(0,10, 0.5 )
        x_test = x_test + 1.0/3.0 * np.random.randn(x_test.size);
        y_test  = np.cos( x_test  * np.pi /7)+  0.1 * np.random.randn(x_test.size)

        return (x_train,y_train) , (x_test, y_test)

# the data, shuffled and split between train and test sets
(x_train, y_train), (x_test, y_test) = SimulData();
xs = np.arange( np.min(x_train), np.max(x_train),0.01 )


#    Line Model 
x_t1 = np.vstack((x_train,np.ones(x_train.shape))).T;
y_t1 = np.zeros((x_train.shape[0],1))
y_t1 = y_train

a = np.dot(np.linalg.inv( np.dot(x_t1.T, x_t1) ), np.dot(x_t1.T,y_t1))
ys = xs * a[0] + a[1]; 
y_pred = x_test * a[0] + a[1]

tst = plt.plot(x_test,y_test,'r.',label='test');
pred = plt.plot(xs,ys,'m',label='pred');
tr = plt.plot(x_train,y_train,'b.',label='train');

errors = []
#Evaluate the Test Error (Mean Square ERROR - MSE)
error1 = np.mean((y_test - y_pred)**2)
print('MSE:',error1)
errors.append(error1)
plt.legend()
plt.show()
print(a)
errors
# Out:
# MSE: 0.12091342357168929
# [-0.22047464  0.86668149]
# [0.12091342357168929]

# %%
# TRY TO FIT HIGHER ORDER MODELS 
# y = a0 + a1 x + a2 x^2  + ... + am x^m
#  FOR MODEL ORDER m = 1,2,3,4,5

# Plot the Test MSE vs model order

# %% [markdown]
# **Second Order(m = 2)**

# %%
x_t1 = np.vstack((x_train**2,x_train,np.ones(x_train.shape))).T;
y_t1 = np.zeros((x_train.shape[0],1))
y_t1 = y_train

a = np.dot(np.linalg.inv( np.dot(x_t1.T, x_t1) ), np.dot(x_t1.T,y_t1))
ys = xs*xs*a[0] + xs * a[1] + a[2]; 
y_pred = x_test*x_test*a[0] + x_test * a[1] + a[2];

tst = plt.plot(x_test,y_test,'r.',label='test');
pred = plt.plot(xs,ys,'m',label='pred');
tr = plt.plot(x_train,y_train,'b.',label='train');

#Evaluate the Test Error (Mean Square ERROR - MSE)
error2 = np.mean((y_test - y_pred)**2)
print('MSE:',error2)
errors.append(error2)
errors
# Out:
# MSE: 0.0557752775645162
# [0.12091342357168929, 0.0557752775645162]

# %%
x_t1 = np.vstack((x_train**3,x_train**2,x_train,np.ones(x_train.shape))).T;
y_t1 = np.zeros((x_train.shape[0],1))
y_t1 = y_train

a = np.dot(np.linalg.inv( np.dot(x_t1.T, x_t1) ), np.dot(x_t1.T,y_t1))
ys = xs*xs*xs*a[0] + xs*xs*a[1] + xs * a[2] + a[3]; 
y_pred = x_test*x_test*x_test*a[0] + x_test*x_test*a[1] + x_test * a[2] + a[3];

tst = plt.plot(x_test,y_test,'r.',label='test');
pred = plt.plot(xs,ys,'m',label='pred');
tr = plt.plot(x_train,y_train,'b.',label='train');

#Evaluate the Test Error (Mean Square ERROR - MSE)
error3 = np.mean((y_test - y_pred)**2)
print('MSE:',error3)
errors.append(error3)
errors
# Out:
# MSE: 0.014453590311112877
# [0.12091342357168929, 0.0557752775645162, 0.014453590311112877]

# %%
x_t1 = np.vstack((x_train**4,x_train**3,x_train**2,x_train,np.ones(x_train.shape))).T;
y_t1 = np.zeros((x_train.shape[0],1))
y_t1 = y_train

a = np.dot(np.linalg.inv( np.dot(x_t1.T, x_t1) ), np.dot(x_t1.T,y_t1))
ys = xs*xs*xs*xs*a[0]+xs*xs*xs*a[1] + xs*xs*a[2] + xs * a[3] + a[4]; 
y_pred = x_test*x_test*x_test*x_test*a[0]+x_test*x_test*x_test*a[1] + x_test*x_test*a[2] + x_test * a[3] + a[4];

tst = plt.plot(x_test,y_test,'r.',label='test');
pred = plt.plot(xs,ys,'m',label='pred');
tr = plt.plot(x_train,y_train,'b.',label='train');

#Evaluate the Test Error (Mean Square ERROR - MSE)
error4 = np.mean((y_test - y_pred)**2)
print('MSE:',error4)
errors.append(error4)
errors
# Out:
# MSE: 0.01160768191048559
# [0.12091342357168929,
#  0.0557752775645162,
#  0.014453590311112877,
#  0.01160768191048559]

# %%
x_t1 = np.vstack((x_train**5,x_train**4,x_train**3,x_train**2,x_train,np.ones(x_train.shape))).T;
y_t1 = np.zeros((x_train.shape[0],1))
y_t1 = y_train

a = np.dot(np.linalg.inv( np.dot(x_t1.T, x_t1) ), np.dot(x_t1.T,y_t1))
ys = xs*xs*xs*xs*xs*a[0]+xs*xs*xs*xs*a[1]+xs*xs*xs*a[2] + xs*xs*a[3] + xs * a[4] + a[5]; 
y_pred = x_test*x_test*x_test*x_test*x_test*a[0]+x_test*x_test*x_test*x_test*a[1]+x_test*x_test*x_test*a[2] + x_test*x_test*a[3] + x_test * a[4] + a[5];

tst = plt.plot(x_test,y_test,'r.',label='test');
pred = plt.plot(xs,ys,'m',label='pred');
tr = plt.plot(x_train,y_train,'b.',label='train');

#Evaluate the Test Error (Mean Square ERROR - MSE)
error5 = np.mean((y_test - y_pred)**2)
print('MSE:',error5)
errors.append(error5)
errors
# Out:
# MSE: 0.012293915456285553
# [0.12091342357168929,
#  0.0557752775645162,
#  0.014453590311112877,
#  0.01160768191048559,
#  0.012293915456285553]

# %%
x_t1 = np.vstack((x_train**6,x_train**5,x_train**4,x_train**3,x_train**2,x_train,np.ones(x_train.shape))).T;
y_t1 = np.zeros((x_train.shape[0],1))
y_t1 = y_train

a = np.dot(np.linalg.inv( np.dot(x_t1.T, x_t1) ), np.dot(x_t1.T,y_t1))
ys = xs*xs*xs*xs*xs*xs*a[0]+xs*xs*xs*xs*xs*a[1]+xs*xs*xs*xs*a[2]+xs*xs*xs*a[3] + xs*xs*a[4] + xs * a[5] + a[6]; 
y_pred = x_test*x_test*x_test*x_test*x_test*x_test*a[0]+x_test*x_test*x_test*x_test*x_test*a[1]+x_test*x_test*x_test*x_test*a[2]+x_test*x_test*x_test*a[3] + x_test*x_test*a[4] + x_test * a[5] + a[6];

tst = plt.plot(x_test,y_test,'r.',label='test');
pred = plt.plot(xs,ys,'m',label='pred');
tr = plt.plot(x_train,y_train,'b.',label='train');

#Evaluate the Test Error (Mean Square ERROR - MSE)
error6 = np.mean((y_test - y_pred)**2)
print('MSE:',error6)
errors.append(error6)
errors
# Out:
# MSE: 0.014808923763171953
# [0.12091342357168929,
#  0.0557752775645162,
#  0.014453590311112877,
#  0.01160768191048559,
#  0.012293915456285553,
#  0.014808923763171953]

# %%
model = ['m1', 'm2', 'm3', 'm4', 'm5', 'm6']
plt.bar(model,errors)
plt.xlabel('N\'th order model')
plt.ylabel('Mean Square Error')
plt.title('MSE Vs Model_Order')
# plt.ylim((0,0.12))
plt.show()
